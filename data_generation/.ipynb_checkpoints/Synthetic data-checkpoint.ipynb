# %%
#import dependencies
import scipy as sp
import pandas as pd
import numpy as np
import copulas as cp
from sklearn.datasets import make_classification, make_regression
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # modifications needed to implement as of 4.30.22:
# * regression set: create Y with a random linear combination of the INFORMATIVE features + noise, then add redundant & nuisance features
# * regression set: generate redundant features via own function, take a random subset of INFORMATIVE FEATURES, apply random linear combination + noise

# %%
#we want to generate synthetic data
#specify:
#-num_rows: number of rows
#-num_informative_features: number of informative features
#-num_redundant_features: number of redundant features (random linear combinations of informative features)
#-num_nuisance_features: uncorrelated features drawn from [-1, 1]

#return:
# a num_rows x (num_informative_features+num_redundant_features+num_nuisance_features + 1 [for target variable]) dataframe
def generate_synthetic_data(num_rows, num_informative_features, num_redundant_features, num_nuisance_features):
    return_df = pd.DataFrame()
    
    return

# %%
#testing make_classification
X_class, y_class = make_classification(n_samples= 500, n_features= 4, n_informative=3, n_redundant= 1,n_classes= 3, shuffle=False)

# %%
X = pd.DataFrame(X_class, columns=["Informative Feature 1", "Informative Feature 2","Informative Feature 3","Redundant Feature 1"])
X.head()
# Out:
#    Informative Feature 1  Informative Feature 2  Informative Feature 3  \
# 0               1.193633               1.663061              -0.275160
# 1               1.048270               1.169108               0.052607
# 2               1.009388               1.361849              -0.470684
# 3              -0.140479               0.782680               0.072643
# 4               1.383343               2.188621               1.056126
#
#    Redundant Feature 1
# 0             0.530091
# 1             0.000069
# 2             0.657977
# 3             0.479941
# 4            -0.594808

# %%
#create nuisance features
def generate_nuisance_features(num_features, num_rows):
    nuisance_features = []
    return_df = pd.DataFrame()
#     columns = [f"Nuisance Feature {i+1}" for i in range(num_features)]
    for j in range(num_features):
        return_df[f"Nuisance Feature {j+1}"] =np.random.uniform(low=-1, high=1, size=(num_rows, ))
   
    return return_df

X_NF = generate_nuisance_features(2, 500)
X_NF
# Out:
#      Nuisance Feature 1  Nuisance Feature 2
# 0              0.426154           -0.287491
# 1             -0.365590           -0.422267
# 2              0.926399           -0.120003
# 3              0.518759           -0.273960
# 4              0.436537           -0.499097
# ..                  ...                 ...
# 495           -0.018954            0.404494
# 496            0.496859            0.936654
# 497            0.496032           -0.568944
# 498           -0.063916            0.830980
# 499            0.851054            0.679144
#
# [500 rows x 2 columns]

# %%
Y = pd.DataFrame(y_class, columns=["Class Y"])
Y.head()
# Out:
#    Class Y
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
classification_set = pd.concat([X, X_NF, Y], axis=1)
classification_set.head()
# Out:
#    Informative Feature 1  Informative Feature 2  Informative Feature 3  \
# 0               1.193633               1.663061              -0.275160
# 1               1.048270               1.169108               0.052607
# 2               1.009388               1.361849              -0.470684
# 3              -0.140479               0.782680               0.072643
# 4               1.383343               2.188621               1.056126
#
#    Redundant Feature 1  Nuisance Feature 1  Nuisance Feature 2  Class Y
# 0             0.530091            0.426154           -0.287491        0
# 1             0.000069           -0.365590           -0.422267        0
# 2             0.657977            0.926399           -0.120003        0
# 3             0.479941            0.518759           -0.273960        0
# 4            -0.594808            0.436537           -0.499097        0

# %%
classification_set.describe()
# Out:
#        Informative Feature 1  Informative Feature 2  Informative Feature 3  \
# count             500.000000             500.000000             500.000000
# mean                0.361022              -0.043199               0.103240
# std                 1.294372               1.375184               1.376230
# min                -3.080036              -3.434761              -2.973624
# 25%                -0.552351              -1.042770              -0.981689
# 50%                 0.510098              -0.009210              -0.185093
# 75%                 1.314371               0.909699               1.120150
# max                 5.263623               4.528129               5.014415
#
#        Redundant Feature 1  Nuisance Feature 1  Nuisance Feature 2     Class Y
# count           500.000000          500.000000          500.000000  500.000000
# mean             -0.349787            0.025081           -0.027651    0.992000
# std               1.953865            0.597228            0.583094    0.815639
# min              -7.758499           -0.994409           -0.996907    0.000000
# 25%              -1.292868           -0.519469           -0.555095    0.000000
# 50%              -0.231758            0.027577           -0.044802    1.000000
# 75%               0.792501            0.573736            0.480852    2.000000
# max               6.211107            0.999065            0.996375    2.000000

# %%
classification_set.corr()
# Out:
#                        Informative Feature 1  Informative Feature 2  \
# Informative Feature 1               1.000000              -0.086425
# Informative Feature 2              -0.086425               1.000000
# Informative Feature 3               0.233075              -0.014612
# Redundant Feature 1                -0.605796               0.464232
# Nuisance Feature 1                  0.062462               0.081654
# Nuisance Feature 2                  0.046445               0.001891
# Class Y                             0.340304              -0.040686
#
#                        Informative Feature 3  Redundant Feature 1  \
# Informative Feature 1               0.233075            -0.605796
# Informative Feature 2              -0.014612             0.464232
# Informative Feature 3               1.000000            -0.799942
# Redundant Feature 1                -0.799942             1.000000
# Nuisance Feature 1                  0.005085             0.005247
# Nuisance Feature 2                  0.019684            -0.031855
# Class Y                            -0.019560            -0.141760
#
#                        Nuisance Feature 1  Nuisance Feature 2   Class Y
# Informative Feature 1            0.062462            0.046445  0.340304
# Informative Feature 2            0.081654            0.001891 -0.040686
# Informative Feature 3            0.005085            0.019684 -0.019560
# Redundant Feature 1              0.005247           -0.031855 -0.141760
# Nuisance Feature 1               1.000000            0.020054  0.029293
# Nuisance Feature 2               0.020054            1.000000  0.079277
# Class Y                          0.029293            0.079277  1.000000

# %%
graph = sns.pairplot(classification_set, diag_kind="kde", kind="scatter")
plt.savefig("pairplot_c.png")
plt.show()

# %%
#testing make_regression
#we are making sure we create 3 features, where all 3 features are INFORMATIVE features
#we will create a function to create the redundant features, since make_regression doesn't have an n_redundant field like make_classification
X_reg, y_reg = make_regression(n_samples= 500, n_features= 3, n_informative=3, shuffle=False)

# %%
#create function to generate the redundant features for the regression dataset
# original_features -- dataframe containing the 
import random

def generate_redundant_features(original_features, n_features):
    if original_features.shape[1] <= 1:
        print("not enough features to work with, minimum needed is 2")
        exit(1)
    
    feature_coefs = {}
    return_df = pd.DataFrame()
    
    for i in range(n_features):
#         print(original_features.columns[[0,1]])
#         print(original_features.shape)
        subset_size = random.randrange(2, original_features.shape[1])
        subset = original_features[random.sample(list(original_features.columns), subset_size)]
#         print(subset)
        coefs = np.random.rand(subset_size)
        
        feature_coefs[f"Redundant Feature {i+1}"] = {"coefs": coefs, "subset_features":subset}
        return_df[f"Redundant Feature {i+1}"] = np.dot(subset, coefs) + np.random.normal(loc=0, scale=1, size=original_features.shape[0])
        
    return return_df, feature_coefs

# %%
X_rf, info = generate_redundant_features(X[X.columns[0:3]], 2)

# %%
# Task: use prev X, X_NF + linear combination (with noise to generate y for regression)
regression_set = pd.concat([X[X.columns[0:3]], X_rf, X_NF], axis=1)
coefs = np.random.rand(3)
print(f"coefs: {coefs}")

regression_set["Y"] = np.dot(X[X.columns[0:3]], coefs) + np.random.normal(loc=0, scale=1, size=500)
regression_set.head()
# Out:
# coefs: [0.95889246 0.65013467 0.5980172 ]
#    Informative Feature 1  Informative Feature 2  Informative Feature 3  \
# 0               1.193633               1.663061              -0.275160
# 1               1.048270               1.169108               0.052607
# 2               1.009388               1.361849              -0.470684
# 3              -0.140479               0.782680               0.072643
# 4               1.383343               2.188621               1.056126
#
#    Redundant Feature 1  Redundant Feature 2  Nuisance Feature 1  \
# 0             2.165974             4.999250            0.426154
# 1             2.080814             0.947664           -0.365590
# 2            -1.679377            -2.235691            0.926399
# 3            -1.775771             0.216632            0.518759
# 4             2.824169             1.844174            0.436537
#
#    Nuisance Feature 2         Y
# 0           -0.287491  3.056697
# 1           -0.422267  3.835411
# 2           -0.120003  1.481992
# 3           -0.273960  0.872008
# 4           -0.499097  1.768313

# %%
regression_set.describe()
# Out:
#        Informative Feature 1  Informative Feature 2  Informative Feature 3  \
# count             500.000000             500.000000             500.000000
# mean                0.361022              -0.043199               0.103240
# std                 1.294372               1.375184               1.376230
# min                -3.080036              -3.434761              -2.973624
# 25%                -0.552351              -1.042770              -0.981689
# 50%                 0.510098              -0.009210              -0.185093
# 75%                 1.314371               0.909699               1.120150
# max                 5.263623               4.528129               5.014415
#
#        Redundant Feature 1  Redundant Feature 2  Nuisance Feature 1  \
# count           500.000000           500.000000          500.000000
# mean              0.061155             0.289032            0.025081
# std               1.744067             1.220245            0.597228
# min              -4.735799            -3.062483           -0.994409
# 25%              -1.128222            -0.522678           -0.519469
# 50%               0.026264             0.295160            0.027577
# 75%               1.351395             1.188021            0.573736
# max               5.119938             4.999250            0.999065
#
#        Nuisance Feature 2           Y
# count          500.000000  500.000000
# mean            -0.027651    0.426838
# std              0.583094    2.108293
# min             -0.996907   -6.611711
# 25%             -0.555095   -1.001614
# 50%             -0.044802    0.611729
# 75%              0.480852    1.775805
# max              0.996375    6.297009

# %%
regression_set.corr()
# Out:
#                        Informative Feature 1  Informative Feature 2  \
# Informative Feature 1               1.000000              -0.086425
# Informative Feature 2              -0.086425               1.000000
# Informative Feature 3               0.233075              -0.014612
# Redundant Feature 1                 0.029966               0.719196
# Redundant Feature 2                 0.449370               0.315468
# Nuisance Feature 1                  0.062462               0.081654
# Nuisance Feature 2                  0.046445               0.001891
# Y                                   0.633173               0.388342
#
#                        Informative Feature 3  Redundant Feature 1  \
# Informative Feature 1               0.233075             0.029966
# Informative Feature 2              -0.014612             0.719196
# Informative Feature 3               1.000000             0.340739
# Redundant Feature 1                 0.340739             1.000000
# Redundant Feature 2                 0.106776             0.302352
# Nuisance Feature 1                  0.005085             0.028860
# Nuisance Feature 2                  0.019684             0.016503
# Y                                   0.522198             0.453670
#
#                        Redundant Feature 2  Nuisance Feature 1  \
# Informative Feature 1             0.449370            0.062462
# Informative Feature 2             0.315468            0.081654
# Informative Feature 3             0.106776            0.005085
# Redundant Feature 1               0.302352            0.028860
# Redundant Feature 2               1.000000            0.064737
# Nuisance Feature 1                0.064737            1.000000
# Nuisance Feature 2                0.012269            0.020054
# Y                                 0.483728            0.062229
#
#                        Nuisance Feature 2         Y
# Informative Feature 1            0.046445  0.633173
# Informative Feature 2            0.001891  0.388342
# Informative Feature 3            0.019684  0.522198
# Redundant Feature 1              0.016503  0.453670
# Redundant Feature 2              0.012269  0.483728
# Nuisance Feature 1               0.020054  0.062229
# Nuisance Feature 2               1.000000  0.032974
# Y                                0.032974  1.000000

# %%
graph = sns.pairplot(regression_set, diag_kind="kde", kind="scatter")
plt.savefig("pairplot_r.png")
plt.show()

# %%
#export to csv for consistency
classification_set.to_csv("./classification_set.csv")
regression_set.to_csv("./regression_set.csv")
